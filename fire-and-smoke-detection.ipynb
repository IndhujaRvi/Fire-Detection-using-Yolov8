# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %% [markdown]
# CONNECT TO THE GOOGLE DRIVE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Git clone method (for development)

# %cd {HOME}
# !git clone github.com/ultralytics/ultralytics
# %cd {HOME}/ultralytics
# !pip install -qe ultralytics

# from IPython import display
# display.clear_output()

# import ultralytics
# ultralytics.checks()

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="08Sy4RN9FT76enmSpOo5")
project = rf.workspace("hackathon-dtmsy").project("fire-sjr7a")
dataset = project.version(3).download("yolov8")
# Out:
# ...
#
# ...
#
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 1.2 MB/s eta 0:00:00
#
# ...
#
# ...
#
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 6.3 MB/s eta 0:00:00
#
# ...
#
# ...
#
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 18.0 MB/s eta 0:00:00
#
# ...
#
# ...
#
# ...
#
# ...
#
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.5 MB/s eta 0:00:00
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 19.0 MB/s eta 0:00:00
#
# ...
#
# ...
#
# ...
#
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 8.0 MB/s eta 0:00:00
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 7.5 MB/s eta 0:00:00
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.1 MB/s eta 0:00:00
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
#   Attempting uninstall: pyparsing
#
#     Found existing installation: pyparsing 3.1.1
#
#     Uninstalling pyparsing-3.1.1:
#
#       Successfully uninstalled pyparsing-3.1.1
#
#   Attempting uninstall: opencv-python-headless
#
# ...

# %%
from ultralytics import YOLO
model=YOLO("yolov8s.pt")
# Out:
# ...
#
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 112MB/s]

# %%
from ultralytics import YOLO
model=YOLO("yolov8s.pt")

model.train(data="/content/Fire-3/data.yaml",epochs=2,imgsz=640, batch=10 )
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
model=YOLO("/content/runs/detect/train4/weights/best.pt")

# %%
model.predict("/content/Fire-3/test/images",save=True)
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
#
# Results saved to runs/detect/predict
# [Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([2, 6])
#  dtype: torch.float32
#   + tensor([[310.00000, 286.00000, 443.00000, 497.00000,   0.94574,   2.00000],
#          [445.00000,  10.00000, 611.00000, 348.00000,   0.94470,   2.00000]], device='cuda:0'),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([5, 6])
#  dtype: torch.float32
#   + tensor([[1.40000e+02, 2.97000e+02, 3.50000e+02, 5.45000e+02, 9.54909e-01, 0.00000e+00],
#          [6.00000e+00, 4.64000e+02, 5.50000e+01, 5.37000e+02, 8.83098e-01, 0.00000e+00],
#          [1.63000e+02, 1.00000e+00, 6.39000e+02, 9.60000e+01, 7.99606e-01, 2.00000e+00],
# ...

# %%
Image(data='/content/runs/detect/train4/confusion_matrix.png', width=600)

# %%
Image(data='/content/runs/detect/train4/val_batch0_labels.jpg', width=600)

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob('/content/runs/detect/predict/middle_-1504-_jpg.rf.385e529bd9e94c2c8c598013c42f4bd4.jpg')[:3]:
      display(Image(filename=image_path, width=600))
      print("\n")
